# %% [markdown]
# # Deep Learning Project : Brain Tumor Semantic Segmentation
# ### Eman Said Al-Hajri
# ### AI and Data Science Stream

# %% [markdown]
# - The project aims to identify tumor regions accurately in Brain within Medical Images using advanced techniques.
#
# - Classes:
#
#    *  Tumor (Class 1)
#    *  Non-Tumor (Class 0)
#
# - Reference: https://www.kaggle.com/datasets/pkdarabi/brain-tumor-image-dataset-semantic-segmentation/data

# %% [markdown]
# --------------

# %% [markdown]
# ### 1. Load Libraries

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import matplotlib.pyplot as plt
import skimage.io
import random
import cv2

# %% [markdown]
# ### 2. Load Dataset

# %%
train_path  = '/home/iman/Desktop/Makeen-AI/DL/DL-Project/Brain_Tumor/train2/'
test_path = '/home/iman/Desktop/Makeen-AI/DL/DL-Project/Brain_Tumor/test2/'
val_path  = '/home/iman/Desktop/Makeen-AI/DL/DL-Project/Brain_Tumor/valid2/'

# %%
train_images = [image for image in os.listdir(train_path) if image[-3:] =='jpg' ]
test_images = [image for image in os.listdir(test_path) if image[-3:] =='jpg' ]
val_images = [image for image in os.listdir(val_path) if image[-3:] =='jpg' ]
len(train_images),len(test_images),len(val_images)
# Out:
# (1402, 206, 418)

# %%
trainMask_path  = '/home/iman/Desktop/Makeen-AI/DL/DL-Project/Brain_Tumor/train_masks2/'
testMask_path = '/home/iman/Desktop/Makeen-AI/DL/DL-Project/Brain_Tumor/test_masks2/'
valMask_path  = '/home/iman/Desktop/Makeen-AI/DL/DL-Project/Brain_Tumor/val_masks2/'

# %%
train_masks = [image for image in os.listdir(trainMask_path) if image[-3:] =='jpg' ]
test_masks = [image for image in os.listdir(testMask_path) if image[-3:] =='jpg' ]
val_masks = [image for image in os.listdir(valMask_path) if image[-3:] =='jpg' ]
len(train_masks),len(test_masks),len(val_masks)
# Out:
# (1402, 206, 418)

# %%
train_images = sorted([f for f in os.listdir(train_path) if f.endswith('jpg')])
train_masks  = sorted([f for f in os.listdir(trainMask_path) if f.endswith('jpg')])

val_images   = sorted([f for f in os.listdir(val_path) if f.endswith('jpg')])
val_masks    = sorted([f for f in os.listdir(valMask_path) if f.endswith('jpg')])

test_images  = sorted([f for f in os.listdir(test_path) if f.endswith('jpg')])
test_masks   = sorted([f for f in os.listdir(testMask_path) if f.endswith('jpg')])

# Check matching lengths
print(f"Train: {len(train_images)} images, {len(train_masks)} masks")
print(f"Val: {len(val_images)} images, {len(val_masks)} masks")
print(f"Test: {len(test_images)} images, {len(test_masks)} masks")
# Out:
# Train: 1402 images, 1402 masks
# Val: 418 images, 418 masks
# Test: 206 images, 206 masks

# %% [markdown]
# ### 3. Explore and Preprocess the Data

# %%
def display_random_images_with_masks_and_boxes(image_dir, mask_dir, num_samples=3):

    image_files = [img for img in os.listdir(image_dir) if img.endswith('.jpg')]
    mask_files = [img for img in os.listdir(mask_dir) if img.endswith('.jpg')]


    selected_images = random.sample(image_files, num_samples)

    for img_name in selected_images:
        img_path = os.path.join(image_dir, img_name)
        mask_path = os.path.join(mask_dir, img_name)


        image = cv2.imread(img_path)
        image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)


        if mask.shape != image.shape[:2]:
            mask = cv2.resize(mask, (image.shape[1], image.shape[0]))


        _, binary_mask = cv2.threshold(mask, 10, 255, cv2.THRESH_BINARY)


        contours, _ = cv2.findContours(binary_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
        combined = image_rgb.copy()
        for cnt in contours:
            x, y, w, h = cv2.boundingRect(cnt)
            cv2.rectangle(combined, (x, y), (x + w, y + h), color=(0, 0, 255), thickness=3)


        plt.figure(figsize=(12, 4))
        plt.subplot(1, 3, 1)
        plt.imshow(image_rgb)
        plt.title('Original')
        plt.axis('off')

        plt.subplot(1, 3, 2)
        plt.imshow(mask, cmap='gray')
        plt.title('Mask')
        plt.axis('off')

        plt.subplot(1, 3, 3)
        plt.imshow(combined)
        plt.title('Combined with Blue Box')
        plt.axis('off')

        plt.tight_layout()
        plt.show()


display_random_images_with_masks_and_boxes(val_path, valMask_path)

# %% [markdown]
# ### 4. Split the Data

# %%
def load_data(image_dir, mask_dir, num_samples, target_size=(512, 512)):
    image_files = sorted([f for f in os.listdir(image_dir) if f.endswith('.jpg')])[:num_samples]
    mask_files  = sorted([f for f in os.listdir(mask_dir) if f.endswith('.jpg')])[:num_samples]

    X, y = [], []
    for img_file, mask_file in zip(image_files, mask_files):
        img_path = os.path.join(image_dir, img_file)
        mask_path = os.path.join(mask_dir, mask_file)

        image = cv2.imread(img_path)
        mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)

        if image is not None and mask is not None:
            image = cv2.resize(image, target_size)
            mask = cv2.resize(mask, target_size)
            X.append(image)
            y.append(mask)
        else:
            print(f"[Skipped] {img_file} or {mask_file}")

    X = np.array(X, dtype=np.float32) / 255.0
    y = np.expand_dims(np.array(y, dtype=np.float32) / 255.0, axis=-1)
    y = (y > 0.5).astype(np.float32)
    return X, y

# %%
import numpy as np
X_train, y_train = load_data(train_path, trainMask_path, 500)
X_val, y_val = load_data(val_path, valMask_path, 250)
X_test, y_test = load_subset(test_path, testMask_path, 200)

print("Train:", X_train.shape, y_train.shape)
print("Val:", X_val.shape, y_val.shape)
print("Test:", X_test.shape, y_test.shape)
# Out:
# Train: (500, 512, 512, 3) (500, 512, 512, 1)
# Val: (250, 512, 512, 3) (250, 512, 512, 1)
# Test: (200, 512, 512, 3) (200, 512, 512, 1)

# %%
import tensorflow as tf

def resize_dataset(images, masks, new_size=(128, 128)):
    images_resized = tf.image.resize(images, new_size)
    masks_resized = tf.image.resize(masks, new_size, method='nearest')  # use nearest to preserve mask classes
    return images_resized.numpy(), masks_resized.numpy()

X_train, y_train = resize_dataset(X_train, y_train)
X_val, y_val = resize_dataset(X_val, y_val)
X_test, y_test = resize_dataset(X_test, y_test)

print("Train:", X_train.shape, y_train.shape)
print("Val:", X_val.shape, y_val.shape)
print("Test:", X_test.shape, y_test.shape)
# Out:
# 2025-07-06 13:23:12.965397: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-07-06 13:23:13.174846: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-07-06 13:23:13.177253: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-07-06 13:23:16.090421: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2025-07-06 13:23:18.872942: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 1572864000 exceeds 10% of free system memory.
# 2025-07-06 13:23:21.543442: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 524288000 exceeds 10% of free system memory.
# 2025-07-06 13:23:22.518062: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 786432000 exceeds 10% of free system memory.
# 2025-07-06 13:23:24.158321: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 629145600 exceeds 10% of free system memory.
# Train: (500, 128, 128, 3) (500, 128, 128, 1)
# Val: (250, 128, 128, 3) (250, 128, 128, 1)
# Test: (200, 128, 128, 3) (200, 128, 128, 1)

# %% [markdown]
# ### 5. Define the Model Architecture

# %%
import tensorflow as tf
from tensorflow.keras import layers, models


def downsample(fm):
    # Con 1*1 s=1
    

def conv_block(inputs, filters):
    x = layers.Conv2D(filters, kernel_size = (3,3), padding = "same")(inputs)
    downsample(int(filters * 0.5))(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)

    # Taking first input and implementing the second conv block
    x2 = layers.Conv2D(filters, kernel_size = (3,3), padding = "same")(x)
    x2 = layers.BatchNormalization()(x2)
    x2 = layers.ReLU()(x2)
    return x2

def encoder_block(inputs, filters):
    x = conv_block(inputs, filters)
    p = layers.MaxPooling2D(pool_size=(2, 2))(x)
    return x, p

def decoder_block(inputs, skip_features, filters):
    x = layers.Conv2DTranspose(filters, kernel_size=(2, 2), strides=2, padding='same')(inputs)
    x = layers.Concatenate()([x, skip_features])
    x = conv_block(x, filters)
    return x

def build_model(f,input_shape=(128, 128, 3), num_classes=1):
    inputs = layers.Input(shape=input_shape)

    # Encoder
    s1, p1 = encoder_block(inputs, 64)
    s2, p2 = encoder_block(p1, 128)
    s3, p3 = encoder_block(p2, 256)
    s4, p4 = encoder_block(p3, 512)

    # Bottleneck
    b1 = conv_block(p4, f)
    b1 = layers.Dropout(0.01)(b1)

    # Decoder
    d1 = decoder_block(b1, s4, 512)
    d2 = decoder_block(d1, s3, 256)
    d3 = decoder_block(d2, s2, 128)
    d4 = decoder_block(d3, s1, 64)

    # Output
    outputs = layers.Conv2D(num_classes, kernel_size=(1, 1), activation='sigmoid')(d4)

    model = models.Model(inputs, outputs)
    return model

# %%
model = build_model(1024, input_shape=(128, 128, 3))
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 128, 128, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 128, 128, 64  1792        ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 128, 128, 64  256        ['conv2d[0][0]']
#  alization)                     )
#
#  re_lu (ReLU)                   (None, 128, 128, 64  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 128, 128, 64  36928       ['re_lu[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 128, 128, 64  256        ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  re_lu_1 (ReLU)                 (None, 128, 128, 64  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 64, 64, 64)   0           ['re_lu_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 64, 64, 128)  73856       ['max_pooling2d[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 64, 64, 128)  512        ['conv2d_2[0][0]']
#  rmalization)
#
#  re_lu_2 (ReLU)                 (None, 64, 64, 128)  0           ['batch_normalization_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 64, 64, 128)  147584      ['re_lu_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 64, 64, 128)  512        ['conv2d_3[0][0]']
#  rmalization)
#
#  re_lu_3 (ReLU)                 (None, 64, 64, 128)  0           ['batch_normalization_3[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 128)  0          ['re_lu_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 32, 32, 256)  295168      ['max_pooling2d_1[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 32, 32, 256)  1024       ['conv2d_4[0][0]']
#  rmalization)
#
#  re_lu_4 (ReLU)                 (None, 32, 32, 256)  0           ['batch_normalization_4[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 32, 32, 256)  590080      ['re_lu_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 32, 32, 256)  1024       ['conv2d_5[0][0]']
#  rmalization)
#
#  re_lu_5 (ReLU)                 (None, 32, 32, 256)  0           ['batch_normalization_5[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 16, 16, 256)  0          ['re_lu_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 16, 16, 512)  1180160     ['max_pooling2d_2[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 16, 16, 512)  2048       ['conv2d_6[0][0]']
#  rmalization)
#
#  re_lu_6 (ReLU)                 (None, 16, 16, 512)  0           ['batch_normalization_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 16, 16, 512)  2359808     ['re_lu_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 16, 16, 512)  2048       ['conv2d_7[0][0]']
#  rmalization)
#
#  re_lu_7 (ReLU)                 (None, 16, 16, 512)  0           ['batch_normalization_7[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 512)   0           ['re_lu_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 8, 8, 1024)   4719616     ['max_pooling2d_3[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 8, 8, 1024)  4096        ['conv2d_8[0][0]']
#  rmalization)
#
#  re_lu_8 (ReLU)                 (None, 8, 8, 1024)   0           ['batch_normalization_8[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 8, 8, 1024)   9438208     ['re_lu_8[0][0]']
#  batch_normalization_9 (BatchNo  (None, 8, 8, 1024)  4096        ['conv2d_9[0][0]']
#  rmalization)
#
#  re_lu_9 (ReLU)                 (None, 8, 8, 1024)   0           ['batch_normalization_9[0][0]']
#
#  dropout (Dropout)              (None, 8, 8, 1024)   0           ['re_lu_9[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 16, 16, 512)  2097664    ['dropout[0][0]']
#  ose)
#
#  concatenate (Concatenate)      (None, 16, 16, 1024  0           ['conv2d_transpose[0][0]',
#                                 )                                 're_lu_7[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 16, 16, 512)  4719104     ['concatenate[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 16, 16, 512)  2048       ['conv2d_10[0][0]']
#  ormalization)
#
#  re_lu_10 (ReLU)                (None, 16, 16, 512)  0           ['batch_normalization_10[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 16, 16, 512)  2359808     ['re_lu_10[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 16, 16, 512)  2048       ['conv2d_11[0][0]']
#  ormalization)
#
#  re_lu_11 (ReLU)                (None, 16, 16, 512)  0           ['batch_normalization_11[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 32, 32, 256)  524544     ['re_lu_11[0][0]']
#  spose)
#
#  concatenate_1 (Concatenate)    (None, 32, 32, 512)  0           ['conv2d_transpose_1[0][0]',
#                                                                   're_lu_5[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 32, 32, 256)  1179904     ['concatenate_1[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 32, 32, 256)  1024       ['conv2d_12[0][0]']
#  ormalization)
#
#  re_lu_12 (ReLU)                (None, 32, 32, 256)  0           ['batch_normalization_12[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 32, 32, 256)  590080      ['re_lu_12[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 32, 32, 256)  1024       ['conv2d_13[0][0]']
#  ormalization)
#
#  re_lu_13 (ReLU)                (None, 32, 32, 256)  0           ['batch_normalization_13[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 64, 64, 128)  131200     ['re_lu_13[0][0]']
#  spose)
#
#  concatenate_2 (Concatenate)    (None, 64, 64, 256)  0           ['conv2d_transpose_2[0][0]',
#                                                                   're_lu_3[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 64, 64, 128)  295040      ['concatenate_2[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 64, 64, 128)  512        ['conv2d_14[0][0]']
#  ormalization)
#
#  re_lu_14 (ReLU)                (None, 64, 64, 128)  0           ['batch_normalization_14[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 64, 64, 128)  147584      ['re_lu_14[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 64, 64, 128)  512        ['conv2d_15[0][0]']
#  ormalization)
#
#  re_lu_15 (ReLU)                (None, 64, 64, 128)  0           ['batch_normalization_15[0][0]']
#
#  conv2d_transpose_3 (Conv2DTran  (None, 128, 128, 64  32832      ['re_lu_15[0][0]']
#  spose)                         )
#
#  concatenate_3 (Concatenate)    (None, 128, 128, 12  0           ['conv2d_transpose_3[0][0]',
#                                 8)                                're_lu_1[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 128, 128, 64  73792       ['concatenate_3[0][0]']
#                                 )
#
#  batch_normalization_16 (BatchN  (None, 128, 128, 64  256        ['conv2d_16[0][0]']
#  ormalization)                  )
#
#  re_lu_16 (ReLU)                (None, 128, 128, 64  0           ['batch_normalization_16[0][0]']
#                                 )
#
#  conv2d_17 (Conv2D)             (None, 128, 128, 64  36928       ['re_lu_16[0][0]']
#                                 )
#
#  batch_normalization_17 (BatchN  (None, 128, 128, 64  256        ['conv2d_17[0][0]']
#  ormalization)                  )
#
#  re_lu_17 (ReLU)                (None, 128, 128, 64  0           ['batch_normalization_17[0][0]']
#                                 )
#
#  conv2d_18 (Conv2D)             (None, 128, 128, 1)  65          ['re_lu_17[0][0]']
#
# ==================================================================================================
# Total params: 31,055,297
# Trainable params: 31,043,521
# Non-trainable params: 11,776
# __________________________________________________________________________________________________

# %%
import tensorflow.keras.backend as K

def dice_coefficient(y_true, y_pred, smooth=1e-7):
    intersection = tf.reduce_sum(y_true * y_pred)
    union = tf.reduce_sum(y_true) + tf.reduce_sum(y_pred)
    dice = (2. * intersection + smooth) / (union + smooth)
    return dice

def dice_loss(y_true, y_pred):
    loss = 1 - dice_coefficient(y_true, y_pred)
    return loss

def iou(y_true, y_pred, smooth=1e-7):
    y_true = K.flatten(y_true)
    y_pred = K.flatten(y_pred)
    intersection = K.sum(y_true * y_pred)
    union = K.sum(y_true) + K.sum(y_pred) - intersection
    return (intersection + smooth) / (union + smooth)

# %% [markdown]
# ### 6. Compile the Model

# %%
model.compile(optimizer='adam',
              loss=dice_loss,
              metrics=['accuracy', dice_coefficient, iou])

# %% [markdown]
# ### 7. Train the Model

# %%
history = model.fit(
    x=X_train,
    y=y_train,
    validation_data=(X_val, y_val),
    epochs=15,
    batch_size=8)
# Out:
# Epoch 1/15
# 63/63 [==============================] - 740s 11s/step - loss: 0.7529 - accuracy: 0.9089 - dice_coefficient: 0.2492 - iou: 0.1469 - val_loss: 0.9592 - val_accuracy: 0.0335 - val_dice_coefficient: 0.0398 - val_iou: 0.0205
# Epoch 2/15
# 63/63 [==============================] - 700s 11s/step - loss: 0.4885 - accuracy: 0.9789 - dice_coefficient: 0.5125 - iou: 0.3509 - val_loss: 0.8886 - val_accuracy: 0.7827 - val_dice_coefficient: 0.1088 - val_iou: 0.0588
# Epoch 3/15
# 63/63 [==============================] - 695s 11s/step - loss: 0.3915 - accuracy: 0.9827 - dice_coefficient: 0.6090 - iou: 0.4425 - val_loss: 0.9442 - val_accuracy: 0.3311 - val_dice_coefficient: 0.0544 - val_iou: 0.0282
# Epoch 4/15
# 63/63 [==============================] - 695s 11s/step - loss: 0.3557 - accuracy: 0.9841 - dice_coefficient: 0.6433 - iou: 0.4814 - val_loss: 0.8226 - val_accuracy: 0.9148 - val_dice_coefficient: 0.1733 - val_iou: 0.0980
# Epoch 5/15
# 63/63 [==============================] - 696s 11s/step - loss: 0.3263 - accuracy: 0.9855 - dice_coefficient: 0.6718 - iou: 0.5121 - val_loss: 0.6475 - val_accuracy: 0.9695 - val_dice_coefficient: 0.3443 - val_iou: 0.2228
# Epoch 6/15
# 63/63 [==============================] - 693s 11s/step - loss: 0.3126 - accuracy: 0.9860 - dice_coefficient: 0.6863 - iou: 0.5275 - val_loss: 0.5441 - val_accuracy: 0.9686 - val_dice_coefficient: 0.4452 - val_iou: 0.3019
# Epoch 7/15
# 63/63 [==============================] - 696s 11s/step - loss: 0.3179 - accuracy: 0.9857 - dice_coefficient: 0.6806 - iou: 0.5225 - val_loss: 0.5652 - val_accuracy: 0.9621 - val_dice_coefficient: 0.4246 - val_iou: 0.2812
# Epoch 8/15
# 63/63 [==============================] - 696s 11s/step - loss: 0.2923 - accuracy: 0.9866 - dice_coefficient: 0.7079 - iou: 0.5544 - val_loss: 0.3624 - val_accuracy: 0.9895 - val_dice_coefficient: 0.6227 - val_iou: 0.4974
# Epoch 9/15
# 63/63 [==============================] - 698s 11s/step - loss: 0.2707 - accuracy: 0.9880 - dice_coefficient: 0.7304 - iou: 0.5816 - val_loss: 0.3188 - val_accuracy: 0.9887 - val_dice_coefficient: 0.6652 - val_iou: 0.5351
# Epoch 10/15
# 63/63 [==============================] - 700s 11s/step - loss: 0.2590 - accuracy: 0.9883 - dice_coefficient: 0.7402 - iou: 0.5931 - val_loss: 0.3275 - val_accuracy: 0.9895 - val_dice_coefficient: 0.6567 - val_iou: 0.5300
# Epoch 11/15
# 63/63 [==============================] - 698s 11s/step - loss: 0.2742 - accuracy: 0.9878 - dice_coefficient: 0.7248 - iou: 0.5746 - val_loss: 0.3486 - val_accuracy: 0.9875 - val_dice_coefficient: 0.6361 - val_iou: 0.4995
# Epoch 12/15
# 63/63 [==============================] - 698s 11s/step - loss: 0.2560 - accuracy: 0.9886 - dice_coefficient: 0.7435 - iou: 0.5976 - val_loss: 0.4267 - val_accuracy: 0.9807 - val_dice_coefficient: 0.5598 - val_iou: 0.4261
# Epoch 13/15
# 63/63 [==============================] - 697s 11s/step - loss: 0.2445 - accuracy: 0.9892 - dice_coefficient: 0.7542 - iou: 0.6122 - val_loss: 0.3177 - val_accuracy: 0.9896 - val_dice_coefficient: 0.6663 - val_iou: 0.5461
# Epoch 14/15
# 63/63 [==============================] - 696s 11s/step - loss: 0.2432 - accuracy: 0.9891 - dice_coefficient: 0.7558 - iou: 0.6141 - val_loss: 0.4463 - val_accuracy: 0.9790 - val_dice_coefficient: 0.5407 - val_iou: 0.3957
# Epoch 15/15
# 63/63 [==============================] - 696s 11s/step - loss: 0.2463 - accuracy: 0.9890 - dice_coefficient: 0.7532 - iou: 0.6104 - val_loss: 0.5397 - val_accuracy: 0.9864 - val_dice_coefficient: 0.4495 - val_iou: 0.3196

# %% [markdown]
# ### 8. Predict and Evaluate the Model

# %%
def test_accuracy(model,X_test, y_test):
    batch_size = 8
    predictions = model.predict(X_test, batch_size=batch_size)

    y_pred = np.squeeze(predictions)
    y_pred = np.expand_dims(y_pred, axis=-1)

    threshold = 0.5
    y_pred_binary = (y_pred >= threshold).astype(np.float32)

    accuracy = np.mean(y_pred_binary == y_test)

    dice_coefficient_score = dice_coefficient(y_test, y_pred)
    dice_loss_score = dice_loss(y_test, y_pred)
    iou_result = iou(y_test, y_pred)
    print(f"Pixel-wise Accuracy: {accuracy:.4f}")
    print(f'Dice Coefficient: {dice_coefficient_score:.4f}')
    print(f'Dice Loss: {dice_loss_score:.4f}')
    print(f'Iou Result: {iou_result:.4f}')

# %%
test_accuracy(model,X_test, y_test)
# Out:
# 25/25 [==============================] - 61s 2s/step
# Pixel-wise Accuracy: 0.9902
# Dice Coefficient: 0.4471
# Dice Loss: 0.5529
# Iou Result: 0.2879

# %%
import matplotlib.pyplot as plt

def plot_training_history(history):
    
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    accuracy = history.history['accuracy']
    val_accuracy = history.history['val_accuracy']
    dice = history.history['dice_coefficient']
    val_dice = history.history['val_dice_coefficient']

    epochs = range(1, len(loss) + 1)

    # Loss
    plt.figure(figsize=(14, 4))
    plt.subplot(1, 3, 1)
    plt.plot(epochs, loss,  label='Training loss')
    plt.plot(epochs, val_loss,  label='Validation loss')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    # Accuracy
    plt.subplot(1, 3, 2)
    plt.plot(epochs, accuracy, label='Training accuracy')
    plt.plot(epochs, val_accuracy, label='Validation accuracy')
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    # Dice Coefficient
    plt.subplot(1, 3, 3)
    plt.plot(epochs, dice,  label='Training Dice')
    plt.plot(epochs, val_dice, label='Validation Dice')
    plt.title('Training and Validation Dice Coefficient')
    plt.xlabel('Epochs')
    plt.ylabel('Dice Coefficient')
    plt.legend()

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### 10. Evaluate the Model and Visualize Results (Metrics/Predictions)

# %%
plot_training_history(history)

# %% [markdown]
# ### 11. Make Predictions

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np
import os

def test_random_images(model, test_path , testMask_path, n=5):
   

    test_images = sorted([f for f in os.listdir(test_path) if f.endswith('.jpg')])

    indices = np.random.choice(len(test_images), size=n, replace=False)

    plt.figure(figsize=(12, 4 * n))
    j = 1
    for idx in indices:
        img_name = test_images[idx]

        img_path = os.path.join(test_path, img_name)
        image = cv2.imread(img_path)
        image = cv2.resize(image, (128, 128))
        image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

        input_array = np.expand_dims(image / 255.0, axis=0)
        mask_pred = model.predict(input_array)[0]
        mask_pred = (mask_pred > 0.5).astype(np.float32) * 255

        mask_path = os.path.join(testMask_path, img_name)
        true_mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
        true_mask = cv2.resize(true_mask, (128, 128))

        plt.subplot(n, 3, j)
        plt.imshow(image_rgb)
        plt.title("Input Image")
        plt.axis('off')
        j += 1

        plt.subplot(n, 3, j)
        plt.imshow(true_mask, cmap='gray')
        plt.title("True Mask")
        plt.axis('off')
        j += 1

        plt.subplot(n, 3, j)
        plt.imshow(mask_pred.squeeze(), cmap='gray')
        plt.title("Predicted Mask")
        plt.axis('off')
        j += 1

    plt.tight_layout()
    plt.show()

# %%
test_random_images(model, test_path , testMask_path)
# Out:
# 1/1 [==============================] - 1s 522ms/step
# 1/1 [==============================] - 0s 426ms/step
# 1/1 [==============================] - 0s 431ms/step
# 1/1 [==============================] - 0s 436ms/step
# 1/1 [==============================] - 0s 419ms/step

# %% [markdown]
# ### 12. Fine-Tune and Optimize

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau , Callback , EarlyStopping, ModelCheckpoint

optimizer = Adam(learning_rate=1e-4)

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, verbose=1)

early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# %%
def combined_loss(y_true, y_pred):
    return (0.5 * tf.keras.losses.binary_crossentropy(y_true, y_pred)) + (0.5 * dice_loss(y_true, y_pred))

# %%
model2 = build_model(512, input_shape=(128, 128, 3))

model2.compile(optimizer=optimizer,
              loss=combined_loss,
              metrics=['accuracy', dice_coefficient, iou])

# %%
history2 = model2.fit(
     x=X_train,
    y=y_train,
    validation_data=(X_val, y_val),
    epochs=20,
    batch_size=8,
    callbacks=[early_stop, reduce_lr]
)
# Out:
# Epoch 1/20
# 63/63 [==============================] - 662s 10s/step - loss: 0.6228 - accuracy: 0.9182 - dice_coefficient: 0.1100 - iou: 0.0589 - val_loss: 0.7299 - val_accuracy: 0.9793 - val_dice_coefficient: 0.0366 - val_iou: 0.0188 - lr: 1.0000e-04
# Epoch 2/20
# 63/63 [==============================] - 648s 10s/step - loss: 0.4686 - accuracy: 0.9812 - dice_coefficient: 0.2281 - iou: 0.1293 - val_loss: 0.6237 - val_accuracy: 0.9793 - val_dice_coefficient: 0.0300 - val_iou: 0.0153 - lr: 1.0000e-04
# Epoch 3/20
# 63/63 [==============================] - 718s 11s/step - loss: 0.4250 - accuracy: 0.9842 - dice_coefficient: 0.2810 - iou: 0.1644 - val_loss: 0.5755 - val_accuracy: 0.9793 - val_dice_coefficient: 0.0291 - val_iou: 0.0148 - lr: 1.0000e-04
# Epoch 4/20
# 63/63 [==============================] - 656s 10s/step - loss: 0.3887 - accuracy: 0.9864 - dice_coefficient: 0.3287 - iou: 0.1978 - val_loss: 0.5563 - val_accuracy: 0.9793 - val_dice_coefficient: 0.0271 - val_iou: 0.0138 - lr: 1.0000e-04
# Epoch 5/20
# 63/63 [==============================] - 649s 10s/step - loss: 0.3605 - accuracy: 0.9880 - dice_coefficient: 0.3684 - iou: 0.2274 - val_loss: 0.5478 - val_accuracy: 0.9793 - val_dice_coefficient: 0.0263 - val_iou: 0.0134 - lr: 1.0000e-04
# Epoch 6/20
# 63/63 [==============================] - 645s 10s/step - loss: 0.3322 - accuracy: 0.9895 - dice_coefficient: 0.4106 - iou: 0.2607 - val_loss: 0.5127 - val_accuracy: 0.9809 - val_dice_coefficient: 0.0760 - val_iou: 0.0402 - lr: 1.0000e-04
# Epoch 7/20
# 63/63 [==============================] - 641s 10s/step - loss: 0.3055 - accuracy: 0.9909 - dice_coefficient: 0.4529 - iou: 0.2951 - val_loss: 0.4250 - val_accuracy: 0.9743 - val_dice_coefficient: 0.2743 - val_iou: 0.1656 - lr: 1.0000e-04
# Epoch 8/20
# 63/63 [==============================] - 657s 10s/step - loss: 0.2843 - accuracy: 0.9906 - dice_coefficient: 0.4889 - iou: 0.3259 - val_loss: 0.4528 - val_accuracy: 0.9842 - val_dice_coefficient: 0.1708 - val_iou: 0.0975 - lr: 1.0000e-04
# Epoch 9/20
# 63/63 [==============================] - 658s 10s/step - loss: 0.2579 - accuracy: 0.9922 - dice_coefficient: 0.5328 - iou: 0.3663 - val_loss: 0.4066 - val_accuracy: 0.9865 - val_dice_coefficient: 0.2492 - val_iou: 0.1494 - lr: 1.0000e-04
# Epoch 10/20
# 63/63 [==============================] - 662s 11s/step - loss: 0.2327 - accuracy: 0.9930 - dice_coefficient: 0.5772 - iou: 0.4088 - val_loss: 0.3063 - val_accuracy: 0.9902 - val_dice_coefficient: 0.4287 - val_iou: 0.2891 - lr: 1.0000e-04
# Epoch 11/20
# 63/63 [==============================] - 664s 11s/step - loss: 0.2074 - accuracy: 0.9941 - dice_coefficient: 0.6206 - iou: 0.4527 - val_loss: 0.3160 - val_accuracy: 0.9900 - val_dice_coefficient: 0.4080 - val_iou: 0.2765 - lr: 1.0000e-04
# Epoch 12/20
# 63/63 [==============================] - 673s 11s/step - loss: 0.1904 - accuracy: 0.9942 - dice_coefficient: 0.6522 - iou: 0.4874 - val_loss: 0.2917 - val_accuracy: 0.9901 - val_dice_coefficient: 0.4551 - val_iou: 0.3195 - lr: 1.0000e-04
# Epoch 13/20
# 63/63 [==============================] - 670s 11s/step - loss: 0.1732 - accuracy: 0.9948 - dice_coefficient: 0.6832 - iou: 0.5226 - val_loss: 0.2896 - val_accuracy: 0.9905 - val_dice_coefficient: 0.4546 - val_iou: 0.3200 - lr: 1.0000e-04
# Epoch 14/20
# 63/63 [==============================] - 669s 11s/step - loss: 0.1571 - accuracy: 0.9950 - dice_coefficient: 0.7133 - iou: 0.5573 - val_loss: 0.3503 - val_accuracy: 0.9872 - val_dice_coefficient: 0.3510 - val_iou: 0.2286 - lr: 1.0000e-04
# Epoch 15/20
# 63/63 [==============================] - 671s 11s/step - loss: 0.1458 - accuracy: 0.9952 - dice_coefficient: 0.7316 - iou: 0.5801 - val_loss: 0.3060 - val_accuracy: 0.9888 - val_dice_coefficient: 0.4310 - val_iou: 0.3027 - lr: 1.0000e-04
# Epoch 16/20
# 63/63 [==============================] - 675s 11s/step - loss: 0.1326 - accuracy: 0.9956 - dice_coefficient: 0.7581 - iou: 0.6131 - val_loss: 0.2394 - val_accuracy: 0.9917 - val_dice_coefficient: 0.5488 - val_iou: 0.4125 - lr: 1.0000e-04
# Epoch 17/20
# 63/63 [==============================] - 695s 11s/step - loss: 0.1184 - accuracy: 0.9961 - dice_coefficient: 0.7828 - iou: 0.6459 - val_loss: 0.2444 - val_accuracy: 0.9916 - val_dice_coefficient: 0.5381 - val_iou: 0.4081 - lr: 1.0000e-04
# Epoch 18/20
# 63/63 [==============================] - 689s 11s/step - loss: 0.1096 - accuracy: 0.9964 - dice_coefficient: 0.7995 - iou: 0.6691 - val_loss: 0.2232 - val_accuracy: 0.9917 - val_dice_coefficient: 0.5797 - val_iou: 0.4407 - lr: 1.0000e-04
# Epoch 19/20
# 63/63 [==============================] - 657s 10s/step - loss: 0.0950 - accuracy: 0.9969 - dice_coefficient: 0.8247 - iou: 0.7043 - val_loss: 0.2403 - val_accuracy: 0.9910 - val_dice_coefficient: 0.5498 - val_iou: 0.4198 - lr: 1.0000e-04
# Epoch 20/20
# 63/63 [==============================] - 660s 10s/step - loss: 0.0902 - accuracy: 0.9969 - dice_coefficient: 0.8345 - iou: 0.7179 - val_loss: 0.2299 - val_accuracy: 0.9907 - val_dice_coefficient: 0.5709 - val_iou: 0.4351 - lr: 1.0000e-04

# %%
test_accuracy(model2,X_test, y_test)
# Out:
# 25/25 [==============================] - 61s 2s/step
# Pixel-wise Accuracy: 0.9929
# Dice Coefficient: 0.5371
# Dice Loss: 0.4629
# Iou Result: 0.3672

# %%
plot_training_history(history2)

# %%
test_random_images(model2, test_path , testMask_path)
# Out:
# 1/1 [==============================] - 0s 439ms/step
# 1/1 [==============================] - 0s 416ms/step
# 1/1 [==============================] - 0s 391ms/step
# 1/1 [==============================] - 0s 376ms/step
# 1/1 [==============================] - 0s 366ms/step

# %% [markdown]
# ### 12. Save and Load the Model
